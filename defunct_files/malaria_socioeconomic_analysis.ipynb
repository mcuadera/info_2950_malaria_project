# %%
# load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
poverty_data = pd.read_csv('poverty.csv')
poverty_data
# Out:
#       Country Name                                        Afghanistan  \
# 0   Indicator Name  Poverty headcount ratio at national poverty li...
# 1             1960                                                NaN
# 2             1961                                                NaN
# 3             1962                                                NaN
# 4             1963                                                NaN
# ..             ...                                                ...
# 57            2016                                               54.5
# 58            2017                                                NaN
# 59            2018                                                NaN
# 60            2019                                                NaN
# 61            2020                                                NaN
#
#                                  Afghanistan.1  \
# 0   Multidimensional poverty index (scale 0-1)
# ...
